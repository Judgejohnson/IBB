# %%
import pandas_datareader.data as web
import pandas as pd

# %%
import datetime

# %%
start = datetime.datetime(2012, 1,1)
end = datetime.datetime(2016,12,31)

# %%
IBB = pd.read_csv('IBB Index.csv')
IBB_list = list(IBB)
IBB_df = web.DataReader(IBB_list,'yahoo',start,end)
# Out:
# C:\Users\jjohnson\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: 'MRNA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\jjohnson\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: 'GH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\jjohnson\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: 'FTSV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\jjohnson\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: 'BBIO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
IBB_df = IBB_df.dropna()

# %%
IBB_df
# Out:
# Attributes  Adj Close                                                          \
# Symbols          ACAD       AKRX       ALKS       ALNY        ALXN       AMAG
# Date
# 2012-01-03   1.110000  11.050000  17.340000   8.660000   70.570000  18.740000
# 2012-01-04   1.090000  11.010000  17.200001   8.650000   70.290001  18.700001
# 2012-01-05   1.100000  11.080000  16.980000   8.650000   72.410004  18.340000
# 2012-01-06   1.150000  10.910000  16.680000   8.670000   74.449997  18.540001
# 2012-01-09   1.190000  11.080000  17.400000   8.850000   74.269997  16.650000
# 2012-01-10   1.280000  11.300000  18.080000   9.000000   74.680000  17.500000
# 2012-01-11   1.310000  11.040000  18.139999   9.260000   73.639999  18.290001
# 2012-01-12   1.320000  10.740000  18.180000  10.080000   74.320000  17.530001
# 2012-01-13   1.260000  10.940000  18.160000   9.880000   74.620003  17.280001
# 2012-01-17   1.270000  10.780000  18.480000  10.470000   77.110001  16.940001
# ...

# %% [markdown]
# IBB_df
